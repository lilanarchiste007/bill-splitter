# %% [markdown]
# <a href="https://colab.research.google.com/github/lilanarchiste007/bill-splitter/blob/main/report_card.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = 'Alice'
print(name, type(name))

is_student = True
print(is_student, type(is_student))

age = 20
print(age, type(age))

score = 80.5
print(isinstance(score, float))
# Out:
# Alice <class 'str'>
# True <class 'bool'>
# 20 <class 'int'>
# True
